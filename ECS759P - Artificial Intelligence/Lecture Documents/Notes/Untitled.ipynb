# %% [markdown]
# ## Artificial Intelligence Lecture 2
#
# ## Running notes:
# - There are changes in the office hours
# - There is a thin line between Robot and softbot, until the hardware takes over from data it is softbot. Example ( Siri, Ok Google, Alexa are softbots, and Dji drone robot) ![Screenshot 2024-10-02 at 9.10.51 AM.png](attachment:20d471b0-d3a4-4736-8a0a-dfc6ce062fe9.png)
#
# >?? why do we want to take down the cost then it is probably satisfying the equation
# > ?? Is the cost function referred to as the performance measure
# > This is because any $$f(x)$$
# > breakdown the match behind the sqrt cost function
#
# - mod helps in getting to zero while always going down, however, the other way is also fine but then it goes up toward the zero from negative
# - Understand PEAS to check if agent design is good
