# %% [markdown]
# # Computer Vision
#
# Computer vision is the ability to teach the computers abilities to perceive information from an image. If your 2 year old can count the number of people and name them from your family group picture, so should the computers also.
#
# However, `Why is vision so difficult?`
#
# Unlike human brains who have the ability to perceive the world in 3D, vision doesn't have the capabilities to perceive the information in 3D, it needs to rely on physics-based and probabilistic models to disambiguate between potential solutions.
#
# Hence, the vision becomes an inverse problem where it relies on uncovering information from the source where there is insuffiecient information to fully understand the information and then answer.
#
# Recreating the world as we see it using the images takes a lot of understanding, it is best put here as follows - _" how objects move and animate, how light reflects off their surfaces, is scattered by the at- mosphere, refracted through camera lenses (or human eyes), and finally projected onto a flat (or curved) image plane"_
#
#
# Different areas where the Vision has now achieved good development:

# %% [markdown]
# <div style="display: flex; flex-wrap: wrap; gap: 15px;">
#
#   <div style="background-color: #e0f7fa; color: #00695c; border: 2px solid #00695c; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Optical character recognition (OCR)</strong><br>
#     Reading handwritten postal codes on letters and automatic number plate recognition.
#   </div>
#
#   <div style="background-color: #fce4ec; color: #c2185b; border: 2px solid #c2185b; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Machine inspection</strong><br>
#     Rapid parts inspection for quality assurance, tolerances on aircraft wings, detecting defects in steel castings using X-ray.
#   </div>
#
#   <div style="background-color: #fff3e0; color: #ef6c00; border: 2px solid #ef6c00; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Retail</strong><br>
#     Object recognition for automated checkout lanes.
#   </div>
#
#   <div style="background-color: #ede7f6; color: #5e35b1; border: 2px solid #5e35b1; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>3D model building (photogrammetry)</strong><br>
#     Fully automated construction of 3D models from aerial photographs, used in Bing Maps.
#   </div>
#
#   <div style="background-color: #f3e5f5; color: #8e24aa; border: 2px solid #8e24aa; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Medical imaging</strong><br>
#     Registering pre-operative and intra-operative imagery, studying brain morphology over time.
#   </div>
#
#   <div style="background-color: #e1f5fe; color: #0277bd; border: 2px solid #0277bd; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Automotive safety</strong><br>
#     Detecting obstacles like pedestrians under conditions where radar or lidar don't work well.
#   </div>
#
#   <div style="background-color: #fff9c4; color: #f9a825; border: 2px solid #f9a825; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Match move</strong><br>
#     Merging CGI with live action by tracking feature points in video for 3D camera motion estimation.
#   </div>
#
#   <div style="background-color: #e8f5e9; color: #388e3c; border: 2px solid #388e3c; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Motion capture (mocap)</strong><br>
#     Using retro-reflective markers and cameras to capture actors for animation.
#   </div>
#
#   <div style="background-color: #ffe0b2; color: #e65100; border: 2px solid #e65100; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Surveillance</strong><br>
#     Monitoring intruders, analyzing highway traffic, and monitoring pools for drowning victims.
#   </div>
#
#   <div style="background-color: #e0f2f1; color: #004d40; border: 2px solid #004d40; padding: 15px; width: 250px; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Fingerprint recognition and biometrics</strong><br>
#     Automatic access authentication and forensic applications.
#   </div>
#
# </div>

# %% [markdown]
# <div style="display: flex; flex-wrap: wrap; gap: 15px; justify-content: center;">
#
#   <div style="background-color: #e0f7fa; color: #00695c; border: 2px solid #00695c; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Optical character recognition (OCR)</strong><br>
#     Reading handwritten postal codes on letters and automatic number plate recognition.
#   </div>
#
#   <div style="background-color: #fce4ec; color: #c2185b; border: 2px solid #c2185b; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Machine inspection</strong><br>
#     Rapid parts inspection for quality assurance, tolerances on aircraft wings, detecting defects in steel castings using X-ray.
#   </div>
#
#   <div style="background-color: #fff3e0; color: #ef6c00; border: 2px solid #ef6c00; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Retail</strong><br>
#     Object recognition for automated checkout lanes.
#   </div>
#
#   <div style="background-color: #ede7f6; color: #5e35b1; border: 2px solid #5e35b1; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>3D model building (photogrammetry)</strong><br>
#     Fully automated construction of 3D models from aerial photographs, used in Bing Maps.
#   </div>
#
#   <div style="background-color: #f3e5f5; color: #8e24aa; border: 2px solid #8e24aa; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Medical imaging</strong><br>
#     Registering pre-operative and intra-operative imagery, studying brain morphology over time.
#   </div>
#
#   <div style="background-color: #e1f5fe; color: #0277bd; border: 2px solid #0277bd; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Automotive safety</strong><br>
#     Detecting obstacles like pedestrians under conditions where radar or lidar don't work well.
#   </div>
#
#   <div style="background-color: #fff9c4; color: #f9a825; border: 2px solid #f9a825; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Match move</strong><br>
#     Merging CGI with live action by tracking feature points in video for 3D camera motion estimation.
#   </div>
#
#   <div style="background-color: #e8f5e9; color: #388e3c; border: 2px solid #388e3c; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Motion capture (mocap)</strong><br>
#     Using retro-reflective markers and cameras to capture actors for animation.
#   </div>
#
#   <div style="background-color: #ffe0b2; color: #e65100; border: 2px solid #e65100; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Surveillance</strong><br>
#     Monitoring intruders, analyzing highway traffic, and monitoring pools for drowning victims.
#   </div>
#
#   <div style="background-color: #e0f2f1; color: #004d40; border: 2px solid #004d40; padding: 15px; width: 45%; border-radius: 10px; box-shadow: 2px 2px 10px rgba(0, 0, 0, 0.1);">
#     <strong>Fingerprint recognition and biometrics</strong><br>
#     Automatic access authentication and forensic applications.
#   </div>
#
# </div>
